# %%
import pandas as pd
from datetime import datetime

# %%
datelist = pd.date_range(start='2018-01-02', end='2021-07-30')
datelist
# Out:
# DatetimeIndex(['2018-01-02', '2018-01-03', '2018-01-04', '2018-01-05',
#                '2018-01-06', '2018-01-07', '2018-01-08', '2018-01-09',
#                '2018-01-10', '2018-01-11',
#                ...
#                '2021-07-21', '2021-07-22', '2021-07-23', '2021-07-24',
#                '2021-07-25', '2021-07-26', '2021-07-27', '2021-07-28',
#                '2021-07-29', '2021-07-30'],
#               dtype='datetime64[ns]', length=1306, freq='D')

# %%
for i in datelist:
    print(i.strftime("%Y%m%d"))
# Out:
# 20180102
# 20180103
# 20180104
# 20180105
# 20180106
# 20180107
# 20180108
# 20180109
# 20180110
# 20180111
# 20180112
# 20180113
# 20180114
# 20180115
# 20180116
# 20180117
# 20180118
# 20180119
# 20180120
# 20180121
# 20180122
# 20180123
# 20180124
# 20180125
# 20180126
# 20180127
# 20180128
# 20180129
# 20180130
# 20180131
# 20180201
# 20180202
# 20180203
# 20180204
# 20180205
# 20180206
# 20180207
# 20180208
# 20180209
# 20180210
# 20180211
# 20180212
# 20180213
# 20180214
# 20180215
# 20180216
# 20180217
# 20180218
# 20180219
# 20180220
# 20180221
# 20180222
# 20180223
# 20180224
# 20180225
# 20180226
# 20180227
# 20180228
# 20180301
# 20180302
# 20180303
# 20180304
# 20180305
# 20180306
# 20180307
# 20180308
# 20180309
# 20180310
# 20180311
# 20180312
# 20180313
# 20180314
# 20180315
# 20180316
# 20180317
# 20180318
# 20180319
# 20180320
# 20180321
# 20180322
# 20180323
# 20180324
# 20180325
# 20180326
# 20180327
# 20180328
# 20180329
# 20180330
# 20180331
# 20180401
# ...

# %%
 datelist = pd.date_range(start='2018-01-02', end='2021-07-30')
    for date in datelist:
        date.strftime("%Y%m%d")
